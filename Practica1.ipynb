# %% [markdown]
# <a href="https://colab.research.google.com/github/JIvanRL/Practica-1/blob/main/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import os
import numpy as np

# %%
data = pd.read_csv('/content/drive/MyDrive/Ejercicio/practica/Casa Habitación_ EstaturaxPeso - Hoja 2.csv')

# %%
data.head(24)
# Out:
#      #  edad  estatura   peso       sexo Signo_Zodiacal  \
# 0    1  24.0    172.00   59.0  Masculino      escorpion
# 1    2  20.0    155.00   55.0   femenino          Libra
# 2    3  20.0    169.00   49.0  Masculino      Escorpion
# 3    4  22.0    190.00   90.0  Masculino          Aries
# 4    5  20.0    160.00   58.0   femenino            Leo
# 5    6  20.0    160.00   85.0   femenino      Sagitario
# 6    7  21.0    150.00   48.0   femenino      Sagitario
# 7    8  20.0    160.00   60.0   femenino          Virgo
# 8    9  21.0    175.00   68.0  Masculino          libra
# 9   10  21.0    183.00   85.0  Masculino          libra
# 10  11  22.0    170.00   70.0  Masculino         Cancer
# 11  12  21.0    164.00   60.0  Masculino          Libra
# 12  13  27.0    178.00   83.0  Masculino      Escorpion
# 13  14  20.0    165.00   55.0  Masculino      Sagitario
# 14  15  24.0    173.00   78.0  Masculino          Virgo
# 15  16  21.0    165.00   80.0   femenino      Escorpion
# ...

# %%
dato_produc = '/content/drive/MyDrive/Ejercicio/practica/Casa Habitación_ EstaturaxPeso - Hoja 2.csv' #nombre del archivo a leer
